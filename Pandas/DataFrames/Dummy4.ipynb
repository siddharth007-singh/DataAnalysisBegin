# %%
import pandas as pd
dv = pd.read_csv("C:\\Users\\Siddharth\\Downloads\\MOCK_DATA.csv")
dv
# Out:
#        id first_name    last_name                        email    gender  \
# 0       1      Julie  Antonognoli   jantonognoli0@linkedin.com      Male
# 1       2      Petey      Burgill          pburgill1@sogou.com      Male
# 2       3   Kathrine      Siggers          ksiggers2@hc360.com    Female
# 3       4     Earvin      Doudney     edoudney3@soundcloud.com  Bigender
# 4       5    Valerye      Ferraro          vferraro4@google.cn    Female
# ..    ...        ...          ...                          ...       ...
# 995   996   Thorsten       Estcot            testcotrn@163.com      Male
# 996   997    Fidelio       Steade       fsteadero@columbia.edu      Male
# 997   998     Rebeka      Cragell             rcragellrp@51.la    Female
# 998   999       Ulla       Harbar  uharbarrq@howstuffworks.com    Female
# 999  1000    Blancha        Poley     bpoleyrr@list-manage.com    Female
#
#           ip_address
# 0     222.105.42.212
# 1      71.104.84.173
# 2     15.214.179.247
# ...

# %%
# na_values will turn blank record to NaN 
dv = pd.read_csv("C:\\Users\\Siddharth\\Downloads\\MOCK_DATA.csv", na_values=["not available", "n.a."])
dv
# Out:
#        id first_name    last_name                        email    gender  \
# 0       1      Julie  Antonognoli   jantonognoli0@linkedin.com      Male
# 1       2      Petey      Burgill          pburgill1@sogou.com      Male
# 2       3   Kathrine      Siggers          ksiggers2@hc360.com    Female
# 3       4     Earvin      Doudney     edoudney3@soundcloud.com  Bigender
# 4       5    Valerye      Ferraro          vferraro4@google.cn    Female
# ..    ...        ...          ...                          ...       ...
# 995   996   Thorsten       Estcot            testcotrn@163.com      Male
# 996   997    Fidelio       Steade       fsteadero@columbia.edu      Male
# 997   998     Rebeka      Cragell             rcragellrp@51.la    Female
# 998   999       Ulla       Harbar  uharbarrq@howstuffworks.com    Female
# 999  1000    Blancha        Poley     bpoleyrr@list-manage.com    Female
#
#           ip_address
# 0     222.105.42.212
# 1      71.104.84.173
# 2     15.214.179.247
# ...

# %%
# if we need to change any particular negative values into NaN, we have to pass as a discionary
dv = pd.read_csv("C:\\Users\\Siddharth\\Downloads\\MOCK_DATA.csv", na_values={
            'ip_address': ["not available", 'n.a.', -1]
})
dv
# Out:
#        id first_name    last_name                        email    gender  \
# 0       1      Julie  Antonognoli   jantonognoli0@linkedin.com      Male
# 1       2      Petey      Burgill          pburgill1@sogou.com      Male
# 2       3   Kathrine      Siggers          ksiggers2@hc360.com    Female
# 3       4     Earvin      Doudney     edoudney3@soundcloud.com  Bigender
# 4       5    Valerye      Ferraro          vferraro4@google.cn    Female
# ..    ...        ...          ...                          ...       ...
# 995   996   Thorsten       Estcot            testcotrn@163.com      Male
# 996   997    Fidelio       Steade       fsteadero@columbia.edu      Male
# 997   998     Rebeka      Cragell             rcragellrp@51.la    Female
# 998   999       Ulla       Harbar  uharbarrq@howstuffworks.com    Female
# 999  1000    Blancha        Poley     bpoleyrr@list-manage.com    Female
#
#           ip_address
# 0     222.105.42.212
# 1      71.104.84.173
# 2     15.214.179.247
# ...

# %%
dv = pd.read_excel("C:\\Users\\Siddharth\\Downloads\\Book.xlsx", "Sheet1")
dv
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0       Apla       Mngo     Orange
