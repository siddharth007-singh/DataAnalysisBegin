# %%
#Making excel data;

import pandas as pd

df = pd.DataFrame({
    "Days": ["1/1/2017", "1/4/2017", "1/5/2017", "1/6/2017", "1/7/2017", "1/8/2017", "1/9/2017", "1/10/2017", "1/11/2017"],
    "Temprature": [32, " ", 28, " " ,32, " ", " ",34, 40], 
    "WindSpeed": [6, 9, " ", 7, " ", " ", " ", 8, 12],
    "Event": ["Rain", "Sunny", "Snow", " ","Rain", "Sunny"," ", "Cloudy", "Sunny"]
})

df
# Out:
#         Days Temprature WindSpeed   Event
# 0   1/1/2017         32         6    Rain
# 1   1/4/2017                    9   Sunny
# 2   1/5/2017         28              Snow
# 3   1/6/2017                    7
# 4   1/7/2017         32              Rain
# 5   1/8/2017                        Sunny
# 6   1/9/2017
# 7  1/10/2017         34         8  Cloudy
# 8  1/11/2017         40        12   Sunny

# %%
#Creating a new xlsx (Excel) File
df.to_excel("Miss Data Handle.xlsx", "Sheet1")

# %%
#Reading the type of everey Cell
type(df.Temprature[1])
# Out:
# str

# %%
df = pd.read_excel("Miss Data Handle.xlsx", "Sheet1", parse_dates=["Days"])
df
# Out:
#    Unnamed: 0       Days Temprature WindSpeed   Event
# 0           0 2017-01-01         32         6    Rain
# 1           1 2017-01-04                    9   Sunny
# 2           2 2017-01-05         28              Snow
# 3           3 2017-01-06                    7
# 4           4 2017-01-07         32              Rain
# 5           5 2017-01-08                        Sunny
# 6           6 2017-01-09
# 7           7 2017-01-10         34         8  Cloudy
# 8           8 2017-01-11         40        12   Sunny

# %%
# For Conformation that Day changed into "TimeStamp"
type(df.Days[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index("Days", inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.set_index("Days", inplace=True)
#       2 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_excel("Miss Data Handle.xlsx", "Sheet1")
df
# Out:
#    Unnamed: 0       Days Temprature WindSpeed   Event
# 0           0   1/1/2017         32         6    Rain
# 1           1   1/4/2017                    9   Sunny
# 2           2   1/5/2017         28              Snow
# 3           3   1/6/2017                    7
# 4           4   1/7/2017         32              Rain
# 5           5   1/8/2017                        Sunny
# 6           6   1/9/2017
# 7           7  1/10/2017         34         8  Cloudy
# 8           8  1/11/2017         40        12   Sunny

# %%
# Set Date column to main index column
df.set_index("Days", inplace=True)

# %%
df
# Out:
#            Unnamed: 0 Temprature WindSpeed   Event
# Days
# 1/1/2017            0         32         6    Rain
# 1/4/2017            1                    9   Sunny
# 1/5/2017            2         28              Snow
# 1/6/2017            3                    7
# 1/7/2017            4         32              Rain
# 1/8/2017            5                        Sunny
# 1/9/2017            6
# 1/10/2017           7         34         8  Cloudy
# 1/11/2017           8         40        12   Sunny

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df = df.fillna(5)
new_df
# Out:
#            Unnamed: 0 Temprature WindSpeed   Event
# Days
# 1/1/2017            0         32         6    Rain
# 1/4/2017            1                    9   Sunny
# 1/5/2017            2         28              Snow
# 1/6/2017            3                    7
# 1/7/2017            4         32              Rain
# 1/8/2017            5                        Sunny
# 1/9/2017            6
# 1/10/2017           7         34         8  Cloudy
# 1/11/2017           8         40        12   Sunny

# %%
new_df = df.fillna({
    "Event": "No Event",
    "Temprature" : 0
})

new_df
# Out:
#            Unnamed: 0 Temprature WindSpeed   Event
# Days
# 1/1/2017            0         32         6    Rain
# 1/4/2017            1                    9   Sunny
# 1/5/2017            2         28              Snow
# 1/6/2017            3                    7
# 1/7/2017            4         32              Rain
# 1/8/2017            5                        Sunny
# 1/9/2017            6
# 1/10/2017           7         34         8  Cloudy
# 1/11/2017           8         40        12   Sunny
